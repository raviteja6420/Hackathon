# %% [markdown]
# ## 1. Which of the following is an invalid identifier?
#      a) 1st_str
#      b) My_str_1
#      c) __
#      d) Foo
#
# **A**

# %% [markdown]
# ## 2. In Python, which of the following is invalid statement?
#
# Abc = 100,000,000
# A,b,c = 100,200,300
# A b c = 100 200 300
# A_b_c = 100,000,000
#
# **C**

# %% [markdown]
# ## 3. Which of the following is an invalid tuple?
#
# tup = (1, 2, 3)
# tup = (1)
# tup = 1, 2, 3
# tup = [1, 2, 3]
#
# **D**

# %% [markdown]
# ## 4. Calculate the dot product and angle between c = (−8, −6) and d = (−4, 5)?
# dot product = -2, acute angle
# dot product = 2, acute angle
# dot product = 2, obtuse angle
# dot product = -2, obtuse angle

# %% [markdown]
# ## 5. Which of the following vectors are orthogonal? (Choose all the correct options)
#
# a = (6,2,-1), b = (2,-7,-2)
# a = (4,-8), b = (-4,-2)
# a = (1,2,-1), b = (2,-3,-2)
# a = (5,2,-2), b = (2,-7,-2)

# %% [markdown]
# ## 6. In Domino's, an average of 3 out of 5 customers ask for ketchup with their Pizza. Assume a random sample of 10 customers is selected. Find the probability that exactly 6 customers ask for ketchup with their Pizza.
#
# 0.20
# 0.25
# 0.30
# 0.35

# %% [markdown]
# ## 7. What are the differences of using squared difference over absolute difference for variance? (Choose all the correct options)
# Square retains the arithmetic signs after computing.
# Square function is continuous and differentiable everywhere.
# Square removes the effects of outliers in the data.
# Square magnifies the outliers in the data.

# %% [markdown]
# ## 8
#
# ![image.png](attachment:aa1bcbe5-890e-4758-98b4-90b2937a991b.png)

# %% [markdown]
# ## 9
#
# ![image (1).png](attachment:65d46579-ab91-49ed-a090-9ee712af4ba9.png)

# %% [markdown]
# ## 10. What is the main advantage of using LSTM over traditional RNNs?
# LSTM has a simpler architecture with fewer parameters.
# LSTM does not suffer from the vanishing gradient problem.
# LSTM can only model short sequences of data.
# LSTM can better capture long-term dependencies in sequential data.

# %% [markdown]
# ## 11. Which technique involves leveraging knowledge gained from solving one problem and applying it to a different, related problem?
#
# a) Fine-tuning
# b) Transfer learning
# c) Attention mechanism
# d) Encoder-decoder architecture

# %% [markdown]
# ## 12. LLMs are:
# a) Usually derived from Transformer architecture (but nor necessarily)
# b) Pre-trained on large corpus and fine-tuned on smaller datasets for specific tasks
# c) Very expensive to train
# d) Not capable of taking Multi-Modal inputs
